# %%
##DONT TOUCH


import pygame
import sys
import random

#random numbers gen for food
x = random.randint(100,1800)
y = random.randint(100,900)
score = 0


pygame.init()
clock = pygame.time.Clock()
game_screen = pygame.display.set_mode((1920,1080))


#border
second_surface = pygame.Surface([1900,1060])
second_surface.fill((0,255,0))

grass_texture = pygame.image.load('Cartoon_green_texture_grass.jpg')
#position=[20,20]
#white=[255,255,255]


#draw food
food = pygame.Rect((x,y,20,20))


#player movement set
player_x = 300
player_y = 300


#user dot
player = pygame.Rect((player_x,player_y,20,20))


while True:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            system.exit()
            
    
            
        if event.type==pygame.KEYDOWN:
            if event.key == pygame.K_LEFT or event.key == ord('a'):
                print('left')
                
                while event.key!=pygame.KEYUP:
                    player_x = player_x - 1
                
                    player = pygame.Rect((player_x,player_y,20,20))
                    
                
            
                

                
                if (player.colliderect(food)):
                    print("hit")
                    x = random.randint(100,1800)
                    y = random.randint(100,900)
                    score = score + 1
                    food = pygame.Rect((x,y,20,20))
                    
            if event.key == pygame.K_RIGHT or event.key == ord('d'):
                print('right')
                player_x = player_x + 20
                
                player = pygame.Rect((player_x,player_y,20,20))

                
                if (player.colliderect(food)):
                    print("hit")
                    x = random.randint(100,1800)
                    y = random.randint(100,900)
                    score = score + 1
                    food = pygame.Rect((x,y,20,20))
                    
            if event.key == pygame.K_UP or event.key == ord('w'):
                print('up')
                player_y = player_y - 20
                
                player = pygame.Rect((player_x,player_y,20,20))
                
                
                if (player.colliderect(food)):
                    print("hit")
                    x = random.randint(100,1800)
                    y = random.randint(100,900)
                    score = score + 1
                    food = pygame.Rect((x,y,20,20))
                    
            if event.key == pygame.K_DOWN or event.key == ord('s'):
                print('down')
                player_y = player_y + 20
                
                player = pygame.Rect((player_x,player_y,20,20))
                
                
                if (player.colliderect(food)):
                    print("hit")
                    x = random.randint(100,1800)
                    y = random.randint(100,900)
                    score = score + 1
                    food = pygame.Rect((x,y,20,20))
                    
                    


        
                
            
    #draws screen/boarder and circle
    game_screen.fill([0,255,200])
    game_screen.blit(second_surface,(10,10))
    pygame.draw.rect(game_screen,(255,0,0),food)
    
    
    pygame.draw.rect(game_screen,(255,255,255),player)

    

    
    #pygame.draw.rect(game_screen,[0,255,200],(0,0,2000,20))
    #pygame.draw.rect(game_screen,[0,255,200],(0,0,20,2000))
    #pygame.draw.rect(game_screen,[0,255,200],(1900,0,700,2000))
    #pygame.draw.rect(game_screen,[0,255,200],(0,1060,2000,20))
    

    pygame.display.flip()
    clock.tick(60)

pygame.quit()

# %%
if event.type == pygame.KEYUP:
            if event.key == pygame.K_LEFT or event.key == ord('a'):
                print('left stop')
            if event.key == pygame.K_RIGHT or event.key == ord('d'):
                print('right stop')
            if event.key == ord('q'):
                pygame.quit()
                sys.exit()

# %%
###ORGANIZED

import pygame
import sys
import random


print("Main start")
    
#random numbers gen for food
x = random.randint(100,1800)
y = random.randint(100,900)
score = 0
print("rand nums gen")
print("x:",x,"     y:",y)
print("Score =",score)

#start pygame
pygame.init()
print("pygame start")
clock = pygame.time.Clock()
print("pygame fps")
game_screen = pygame.display.set_mode((1920,1080))
print("pygame win size")
    
game_screen.fill([0,255,200])
print("screen fill")
    
#boarder create
second_surface = pygame.Surface([1900,1060])
print("second surface made")
second_surface.fill((0,255,0))
print("filled...")
game_screen.blit(second_surface,(10,10))
print("Built.")


    
#create food
food = pygame.Rect((x,y,20,20))
print("Food was made")


print("just before while loop")
while True:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            system.exit()



        if event.type==pygame.KEYDOWN:
            if event.key == pygame.K_LEFT or event.key == ord('a'):
                print('left')

                while event.key!=pygame.KEYUP:
                    player_x = player_x - 1

                    player = pygame.Rect((player_x,player_y,20,20))





                if (player.colliderect(food)):
                    print("hit")
                    x = random.randint(100,1800)
                    y = random.randint(100,900)
                    score = score + 1
                    food = pygame.Rect((x,y,20,20))

            if event.key == pygame.K_RIGHT or event.key == ord('d'):
                print('right')
                player_x = player_x + 20

                player = pygame.Rect((player_x,player_y,20,20))


                if (player.colliderect(food)):
                    print("hit")
                    x = random.randint(100,1800)
                    y = random.randint(100,900)
                    score = score + 1
                    food = pygame.Rect((x,y,20,20))

            if event.key == pygame.K_UP or event.key == ord('w'):
                print('up')
                player_y = player_y - 20

                player = pygame.Rect((player_x,player_y,20,20))


                if (player.colliderect(food)):
                    print("hit")
                    x = random.randint(100,1800)
                    y = random.randint(100,900)
                    score = score + 1
                    food = pygame.Rect((x,y,20,20))

            if event.key == pygame.K_DOWN or event.key == ord('s'):
                print('down')
                player_y = player_y + 20

                player = pygame.Rect((player_x,player_y,20,20))


                if (player.colliderect(food)):
                    print("hit")
                    x = random.randint(100,1800)
                    y = random.randint(100,900)
                    score = score + 1
                    food = pygame.Rect((x,y,20,20))
                        
        #draw food
        pygame.draw.rect(game_screen,(255,0,0),food)
        print("draw FOOD!!")






class Player:
    def __init__(self,x,y):
        self.x = x
        self.y = y
        
        self.player_color = (255, 255, 255)
        self.speed_x = 0
        self.speed_y = 0
        
        self.up = false
        self.down = false
        self.right = false
        self.left = false
        
        self.speed = 5;
        

    def draw(self, game_screen):
        pygame.draw.rect((game_screen), (self.color, self.rect))
        

    def movement(self):
        self.speed_x = 0
        self.speed_y = 0
        
class Food:
    def __init__(self, value, x, y):
        self.x = x
        self.y = y
        
        self.value = 0
    
    def draw(self, game_screen):
        pygame.draw.rect((game_screen),(255,0,0),self.rect)
        
    def collision(self, player_position):
        print("no")

# %%
SCREEN_WIDTH = 1920
SCREEN_HEIGHT = 1080

WHITE = (255,255,255)
RED = (255,0,0)
GREEN = (0,255,0)
BLUE = (0,0,255)



import pygame
import sys
import random

game_run = True

def main():

    
    
    food_x = random.randint(100,1800)
    food_y = random.randint(100,900)
    
    
    player_x = 960
    player_y = 540

    #player_direction = ""
    
    player = pygame.Rect((player_x,player_y,20,20))
    food = pygame.Rect((food_x,food_y,20,20))
    
    
    #game started
    Game.draw(player_x,player_y,food_x,food_y)
    
    clock = pygame.time.Clock()

    Food.food_generate(player_x,player_y,food_x,food_y)
    #Snake.draw(player_direction,player_x,player_y)
    
    
    while game_run:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                system.exit()
                
        if event.type==pygame.KEYDOWN:
            if event.key == pygame.K_LEFT or event.key == ord('a'):
                print('left')
                
                player_x = player_x - 20
                player_y = player_y
                
                Snake.move(player_x,player_y,food_x,food_y)
                player = pygame.Rect((player_x,player_y,20,20))
 


                if (player.colliderect(food)):
                    print("hit")
                    Snake.collide(player_x,player_y,food_x,food_y)
                    
            if event.key == pygame.K_RIGHT or event.key == ord('d'):
                print('right')
                
                player_x = player_x + 20
                player_y = player_y
                
                Snake.move(player_x,player_y,food_x,food_y)
                player = pygame.Rect((player_x,player_y,20,20))
                
                if (player.colliderect(food)):
                    print("hit")
                    Snake.collide(player_x,player_y,food_x,food_y)
                    
            if event.key == pygame.K_UP or event.key == ord('w'):
                print('up')
                
                player_y = player_y - 20
                player_x = player_x
                
                Snake.move(player_x,player_y,food_x,food_y)
                player = pygame.Rect((player_x,player_y,20,20))
                
                if (player.colliderect(food)):
                    print("hit")
                    Snake.collide(player_x,player_y,food_x,food_y)
                    
                    
            if event.key == pygame.K_DOWN or event.key == ord('s'):
                print('down')
                
                player_y = player_y + 20
                player_x = player_x
                
                Snake.move(player_x,player_y,food_x,food_y)
                player = pygame.Rect((player_x,player_y,20,20))
                
                if (player.colliderect(food)):
                    print("hit")
                    Snake.collide(player_x,player_y,food_x,food_y)
                
                
            

        pygame.display.flip()
        clock.tick(60)

        
        
class Game():
    
    def __init__(self,player_x,player_y):
        pygame.init()
        self.Snake.draw()
        
        
    
    def draw(player_x,player_y,food_x,food_y):
        
        
        
        game_screen = pygame.display.set_mode((SCREEN_WIDTH,SCREEN_HEIGHT))
        game_screen.fill([0,255,200])
        
        second_surface = pygame.Surface([1900,1060])
        second_surface.fill((GREEN))
        game_screen.blit(second_surface,(10,10))
        
        player = pygame.Rect((player_x,player_y,20,20))
        pygame.draw.rect(game_screen,(255,255,255),player)
        
        food = pygame.Rect((food_x,food_y,20,20))
        pygame.draw.rect(game_screen,(255,0,0),food)
        
        
        
   
        
        
class Snake(object):
    def __init__(self):
        self.length = 1
        self.color = ((WHITE))
        self.player_x = 960
        self.player_y = 540
        
    def move(player_x,player_y,food_x,food_y):
        
        Game.draw(player_x,player_y,food_x,food_y)

 
    def collide(player_x,player_y,food_x,food_y):
        print("hit")
        food_x = random.randint(100,1800)
        food_y = random.randint(100,900)
        Game.draw(player_x,player_y,food_x,food_y)
        
        
  
        
        
class Food(object):
    def __init__(self):
        self.value = 1
        
    def food_generate(player_x,player_y,food_x,food_y):
        Game.draw(player_x,player_y,food_x,food_y)
        
        
        
    
    

if __name__ == "__main__":
    main()

# %%
import pygame
import sys
import random

game_run = True

def main():
    
    #food starting position and player score
    food_x = random.randint(50,380)
    food_y = random.randint(50,380)
    score = 0
    
    #player starting position
    player_x = 300
    player_y = 300

    
    #game started, background made
    pygame.init()
    clock = pygame.time.Clock()
    game_screen = pygame.display.set_mode((480,480))
    game_screen.fill([0,255,0])
    
    
    #create food
    food = pygame.Rect((food_x,food_y,20,20))
    
    #create player
    player = pygame.Rect((player_x,player_y,20,20))
    
    while game_run:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                system.exit()
                
        if event.type==pygame.KEYDOWN:
            if event.key == pygame.K_LEFT or event.key == ord('a'):
                print('left')
                player_x = player_x - 20
                player = pygame.Rect((player_x,player_y,20,20))
                

                
                if (player.colliderect(food)):
                    print("hit")
                    pygame.draw.rect(game_screen,(255,255,255),player)
                    x = random.randint(50,380)
                    y = random.randint(50,380)
                    score = score + 1
                    food = pygame.Rect((x,y,20,20))
                    
            if event.key == pygame.K_RIGHT or event.key == ord('d'):
                print('right')
                player_x = player_x + 20
                
                player = pygame.Rect((player_x,player_y,20,20))

                
                if (player.colliderect(food)):
                    print("hit")
                    pygame.draw.rect(game_screen,(255,255,255),player)
                    x = random.randint(50,380)
                    y = random.randint(50,380)
                    score = score + 1
                    food = pygame.Rect((x,y,20,20))
                    
            if event.key == pygame.K_UP or event.key == ord('w'):
                print('up')
                player_y = player_y - 20
                
                player = pygame.Rect((player_x,player_y,20,20))
                
                
                if (player.colliderect(food)):
                    print("hit")
                    pygame.draw.rect(game_screen,(255,255,255),player)
                    x = random.randint(50,380)
                    y = random.randint(50,380)
                    score = score + 1
                    food = pygame.Rect((x,y,20,20))
                    
            if event.key == pygame.K_DOWN or event.key == ord('s'):
                print('down')
                
                player_y = player_y + 20        
                player = pygame.Rect((player_x,player_y,20,20))
                
                
                if (player.colliderect(food)):
                    print("hit")
                    
                    pygame.draw.rect(game_screen,(255,255,255),player)
                    
                    x = random.randint(50,380)
                    y = random.randint(50,380)
                    
                    score = score + 1
                    food = pygame.Rect((x,y,20,20))
    
        #display screen
        pygame.draw.rect(game_screen,(255,0,0),food)
        pygame.draw.rect(game_screen,(255,255,255),player)
        pygame.display.flip()
        clock.tick(60)
        
        


if __name__ == "__main__":
    main()
# Out:
# left
# hit
# left
# left
# left
# left
# left
# left
# left
# up
# up
# up
# up
# up
# up
# up
# up
# up
# up
# up
# right
# right
# right
# right
# right
# right
# right
# down
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-92b015c1f233> in <module>
#     112
#     113 if __name__ == "__main__":
# --> 114     main()
#
# <ipython-input-4-92b015c1f233> in main()
#      86
#      87                 player_y = player_y + 20
# ---> 88                 game_screen.blit(second_surface,(10,10))
#      89
#      90                 player = pygame.Rect((player_x,player_y,20,20))
#
# NameError: name 'second_surface' is not defined
